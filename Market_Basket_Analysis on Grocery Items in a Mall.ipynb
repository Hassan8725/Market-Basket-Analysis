# %% [markdown]
# # Objevtive : Market Basket Analysis

# %% [markdown]
# #### This File contains information about Customers buying different grocery items at a Mall.
# #### Features:
# ##### Currently we dont have any features and we will make them in Data Preprocessing
# ##### We have to first analyse this data and as we can see that each row is a transaction we have to make columns by items present in the market and map all the transactions to them so we can relate and associate different rules
#
# ### Steps:
# * Importing necessary Libraries and Data
# * Data Preprocessing
# * Data Encoding
# * Apriori Algorithm
# * Association Rules
# * Association Rules (Without Mineral Water)

# %% [markdown]
# # Importing Necessary Libraries and Data

# %% [markdown]
# pip install mlxtend

# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
#Load Dataset
df = pd.read_csv('C:/Users/Hassan Ahmed/Desktop/Data Science Cohort-1 FTI/Market_Basket_Optimisation.csv',header = None)
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
df.describe()
# Out:
#                    0              1              2              3          4   \
# count            7501           5747           4389           3345       2529
# unique            115            117            115            114        110
# top     mineral water  mineral water  mineral water  mineral water  green tea
# freq              577            484            375            201        153
#
#                   5          6          7          8          9   \
# count           1864       1369        981        654        395
# unique           106        102         98         88         80
# top     french fries  green tea  green tea  green tea  green tea
# freq             107         96         67         57         31
#
#                     10         11         12         13         14      15  \
# count              256        154         87         47         25       8
# unique              66         50         43         28         19       8
# ...

# %% [markdown]
# # Data Preprocessing

# %%
# making each customers shopping items an identical list
transactions = []
for a in range(0, 7501):
    transactions.append([str(df.values[a,b]).strip() for b in range(0, 20)])

# conveting it into an numpy array
transactions = np.array(transactions)

# checking the shape of the array
print(transactions.shape)
# Out:
# (7501, 20)

# %% [markdown]
# # Data Encoding

# %%
trans_enc = TransactionEncoder()
Enc_data = trans_enc.fit_transform(transactions)
Enc_data = pd.DataFrame(Enc_data, columns = trans_enc.columns_)

# getting the shape of the data
Enc_data.columns=Enc_data.columns.str.strip()
Enc_data.shape
# Out:
# (7501, 120)

# %%
Enc_data.head()
# Out:
#    almonds  antioxydant juice  asparagus  avocado  babies food  bacon  \
# 0     True               True      False     True        False  False
# 1    False              False      False    False        False  False
# 2    False              False      False    False        False  False
# 3    False              False      False     True        False  False
# 4    False              False      False    False        False  False
#
#    barbecue sauce  black tea  blueberries  body spray  ...  turkey  \
# 0           False      False        False       False  ...   False
# 1           False      False        False       False  ...   False
# 2           False      False        False       False  ...   False
# 3           False      False        False       False  ...    True
# 4           False      False        False       False  ...   False
#
#    vegetables mix  water spray  white wine  whole weat flour  \
# 0            True        False       False              True
# ...

# %%
def encode_units(x):
    if x==False:
        return 0
    if x==True:
        return 1

basket_sets=Enc_data.applymap(encode_units)
basket_sets.drop("nan",inplace=True,axis=1)

# %% [markdown]
# # Apriori Algorithm

# %% [markdown]
# Generating Frequent item set with a chosen support threshold value
# We can now generate frequent item sets that have a support of at least 5%

# %%
frequent_itemsets = apriori(basket_sets, min_support = 0.05, use_colnames=True)

# %% [markdown]
# # Association Rules

# %% [markdown]
# Generating Rules
# The final step is to generate the rules with their corresponding support, confidence and lift.

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)
rules
# Out:
#        antecedents      consequents  antecedent support  consequent support  \
# 0  (mineral water)      (chocolate)            0.238368            0.163845
# 1      (chocolate)  (mineral water)            0.163845            0.238368
# 2           (eggs)  (mineral water)            0.179709            0.238368
# 3  (mineral water)           (eggs)            0.238368            0.179709
# 4      (spaghetti)  (mineral water)            0.174110            0.238368
# 5  (mineral water)      (spaghetti)            0.238368            0.174110
#
#     support  confidence      lift  leverage  conviction
# 0  0.052660    0.220917  1.348332  0.013604    1.073256
# 1  0.052660    0.321400  1.348332  0.013604    1.122357
# 2  0.050927    0.283383  1.188845  0.008090    1.062815
# 3  0.050927    0.213647  1.188845  0.008090    1.043158
# 4  0.059725    0.343032  1.439085  0.018223    1.159314
# 5  0.059725    0.250559  1.439085  0.018223    1.102008

# %% [markdown]
# ##### Unique Combinations

# %%
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
# getting th item sets with length = 2 and support more han 10%
frequent_itemsets[ (frequent_itemsets['length'] == 2) &
                   (frequent_itemsets['support'] >= 0.05) ].reset_index(drop=True)
# Out:
#     support                    itemsets  length
# 0  0.052660  (mineral water, chocolate)       2
# 1  0.050927       (eggs, mineral water)       2
# 2  0.059725  (spaghetti, mineral water)       2

# %% [markdown]
# ##### Analysis
# 1. We can see that there are quite a few rules with a high lift value which means that it occurs more frequently than would be expected given the number of transaction and product combinations.
# 2. We can also see several where the confidence is high as well. This part of the analysis is where the domain knowledge will come in handy.

# %% [markdown]
# We can filter the dataframe and, look for a lift of 1 and confidence 0.2.

# %%
rules[ (rules['lift'] >= 1) &
       (rules['confidence'] >= 0.3) ]
# Out:
#    antecedents      consequents  antecedent support  consequent support  \
# 1  (chocolate)  (mineral water)            0.163845            0.238368
# 4  (spaghetti)  (mineral water)            0.174110            0.238368
#
#     support  confidence      lift  leverage  conviction
# 1  0.052660    0.321400  1.348332  0.013604    1.122357
# 4  0.059725    0.343032  1.439085  0.018223    1.159314

# %% [markdown]
# ##### Results of Analysis
# 1. In looking at the rules, it seems that the mineral water and spaghetti as well as chocolate and mineral water are purchased together more often.

# %% [markdown]
# # Association Rules (Without Mineral Water)

# %% [markdown]
# #### As we can see that ** mineral water ** is constant in all our rules so by excluding this we are now going to analyse other rules as well.

# %%
basket_sets.drop("mineral water",inplace=True,axis=1)

# %%
frequent_itemsets1 = apriori(basket_sets, min_support = 0.02, use_colnames=True)

# %%
rules1 = association_rules(frequent_itemsets1, metric="confidence", min_threshold=0.2)
rules1
# Out:
#             antecedents     consequents  antecedent support  \
# 0             (burgers)          (eggs)            0.087188
# 1             (burgers)  (french fries)            0.087188
# 2             (burgers)     (spaghetti)            0.087188
# 3           (chocolate)          (eggs)            0.163845
# 4        (french fries)     (chocolate)            0.170911
# 5           (chocolate)  (french fries)            0.163845
# 6   (frozen vegetables)     (chocolate)            0.095321
# 7         (ground beef)     (chocolate)            0.098254
# 8                (milk)     (chocolate)            0.129583
# 9           (spaghetti)     (chocolate)            0.174110
# 10          (chocolate)     (spaghetti)            0.163845
# 11       (french fries)          (eggs)            0.170911
# 12               (eggs)  (french fries)            0.179709
# 13  (frozen vegetables)          (eggs)            0.095321
# 14               (milk)          (eggs)            0.129583
# ...

# %% [markdown]
# ##### Unique Combinations

# %%
frequent_itemsets1['length'] = frequent_itemsets1['itemsets'].apply(lambda x: len(x))
# getting th item sets with length = 2 and support more han 10%
frequent_itemsets1[(frequent_itemsets1['length'] == 2) &
                   (frequent_itemsets1['support'] >= 0.02)].reset_index(drop=True)
# Out:
#      support                        itemsets  length
# 0   0.028796                 (burgers, eggs)       2
# 1   0.021997         (burgers, french fries)       2
# 2   0.021464            (burgers, spaghetti)       2
# 3   0.033196               (eggs, chocolate)       2
# 4   0.034395       (french fries, chocolate)       2
# 5   0.022930  (frozen vegetables, chocolate)       2
# 6   0.023464          (green tea, chocolate)       2
# 7   0.023064        (ground beef, chocolate)       2
# 8   0.032129               (milk, chocolate)       2
# 9   0.039195          (spaghetti, chocolate)       2
# 10  0.036395            (french fries, eggs)       2
# 11  0.021730       (eggs, frozen vegetables)       2
# 12  0.025463               (green tea, eggs)       2
# 13  0.030796                    (eggs, milk)       2
# 14  0.021730                (pancakes, eggs)       2
# 15  0.036528               (eggs, spaghetti)       2
# 16  0.028530       (green tea, french fries)       2
# ...

# %% [markdown]
# ##### Analysis
# 1. We can see that there are quite a few rules with a high lift value which means that it occurs more frequently than would be expected given the number of transaction and product combinations.
# 2. We can also see several where the confidence is high as well. This part of the analysis is where the domain knowledge will come in handy.

# %% [markdown]
# We can filter the dataframe and, look for a lift of 1.5 and confidence 0.2.

# %%
rules1[ (rules1['lift'] >= 1.5) &
       (rules1['confidence'] >= 0.2) ].reset_index(drop=True)
# Out:
#             antecedents    consequents  antecedent support  \
# 0             (burgers)         (eggs)            0.087188
# 1                (milk)    (chocolate)            0.129583
# 2   (frozen vegetables)         (milk)            0.095321
# 3   (frozen vegetables)    (spaghetti)            0.095321
# 4         (ground beef)         (milk)            0.098254
# 5           (spaghetti)  (ground beef)            0.174110
# 6         (ground beef)    (spaghetti)            0.098254
# 7           (spaghetti)         (milk)            0.174110
# 8                (milk)    (spaghetti)            0.129583
# 9           (olive oil)    (spaghetti)            0.065858
# 10           (pancakes)    (spaghetti)            0.095054
# 11             (shrimp)    (spaghetti)            0.071457
# 12           (tomatoes)    (spaghetti)            0.068391
#
#     consequent support   support  confidence      lift  leverage  conviction
# ...

# %% [markdown]
# ##### Results of Analysis
# 1. In looking at the rules, it seems that the ground beef and spaghetti are purchased together more often.
# 2. Milk and Chocolate, Frozen Vegetables and spaghetti, etc are purchased togetter more often.
